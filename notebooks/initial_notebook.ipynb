# %%
#to_keep = df[df.groupby(['a', 'b', 'c'])['result'].transform('nunique') == 1] #duplicates
#duplicate_rows = df[df.duplicated()]
#print(duplicate_rows)
#df.drop_duplicates(inplace=True)
#handling duplicates

# df_duplicates= df.drop_duplicates(inplace=True) 
#print("Missing values:\n", data.isnull().sum())

# %% [markdown]
# https://github.com/DiabSaeed/World_population_analysis/blob/main/Analysis/actual_analysis.py
# https://griddb.net/en/blog/analyzing-world-population-data-in-python/
# https://www.w3schools.com/python/pandas/pandas_correlations.asp
# https://stackoverflow.com/questions/18866657/nonetype-object-is-not-subscriptable
#
# #https://www.webpages.uidaho.edu/~stevel/cheatsheets/Pandas%20DataFrame%20Notes_12pages.pdf
#
# #https://blog.devgenius.io/5-essential-data-quality-checks-you-can-perform-with-python-18fc87655950
# #https://medium.com/@swaratvaghela30112003/working-with-csv-and-json-in-python-fc88e49c1c1d
# https://realpython.com/python-data-cleaning-numpy-pandas/
#
# #https://stackoverflow.com/questions/61909261/how-can-we-detect-inconsistency-in-pandas-dataframe
#              #https://www.webpages.uidaho.edu/~stevel/cheatsheets/Pandas%20DataFrame%20Notes_12pages.pdf

# %% [markdown]
# my bib.
# https://datacarpentry.github.io/python-socialsci/07-json.html
# https://stackoverflow.com/questions/6740918/creating-a-dictionary-from-a-csv-file
# https://medium.com/@swaratvaghela30112003/working-with-csv-and-json-in-python-fc88e49c1c1d
# https://medium.com/@swaratvaghela30112003/working-with-csv-and-json-in-python-fc88e49c1c1d
# https://www.webpages.uidaho.edu/~stevel/cheatsheets/Pandas%20DataFrame%20Notes_12pages.pdf
# https://medium.com/@__jimchng__/data-validation-with-pandas-an-aside-with-python-decorators-7ab5e193b891#:~:text=pandas%20is%20a%20popular%20Python%20package%2C%20it%20enables,use%20pandas%E2%80%99%20built-in%20APIs%2C%20such%20as%20the%20pandas.Series.isin%28values%29.

# %% [markdown]
#   df = pd.read_csv('data\Scotland_teaching_file_1PCT.csv')
# C:\Users\Emmie\OneDrive - University of St Andrews\CS5002_P3\initialscript.py:12: SyntaxWarning: invalid escape sequence '\d'
#   with open("data\data_dictionary.json", "r") as jsonfile:
# Hello World!
# Empty DataFrame
# Columns: [Record_Number, Region, RESIDENCE_TYPE, Family_Composition, sex, age, Marital_Status, student, Country_Of_Birth, health, Ethnic_Group, religion, Economic_Activity, Occupation, industry, Hours_Worked_Per_Week, Approximate_Social_Grade]
# Index: []
# ['C:\\Users\\Emmie\\OneDrive - University of St Andrews\\CS5002_P3\\initialscript.py']
# PS C:\Users\Emmie\OneDrive - University of St Andrews\CS5002_P3>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
  File "c:\Users\Emmie\.vscode\extensions\ms-python.debugpy-2024.12.0-win32-x64\bundled\libs\debugpy\_vendored\pydevd\_pydevd_bundle\pydevd_runpy.py", line 283, in _get_code_from_file
    code = compile(f.read(), fname, "exec")
           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
  File "C:\Users\Emmie\OneDrive - University of St Andrews\CS5002_P3\initialscript.py", line 42
    df[column]=df[column].apply(lambda row: min_val<= row[] max_val) #error
                                            ^^^^^^^^^^^^^^^
SyntaxError: invalid syntax. Perhaps you forgot a comma?
PS C:\Users\Emmie\OneDrive - University of St Andrews\CS5002_P3>

# %% [markdown]
# used a dictionary but found pandas automated

# %%
    #https://stackoverflow.com/questions/3294889/iterating-over-dictionaries-using-for-loops
    #https://docs.python.org/3/tutorial/datastructures.html#dictionaries

# %%
def get_expected_types_from_data_dictionary(data_dict):
    expected_types = {} #make a dictionary with keys 
    for key in data_dict_keys.():
        if isinstance (data_dict[key], dict):
            expected_types[key] = 'int' if list(data_dict[key].keys())[0].isdigit() else 'string'
            return expected_types

# %%
Exception has occurred: AttributeError
'function' object has no attribute 'replace'
  File "C:\Users\Emmie\OneDrive - University of St Andrews\CS5002_P3\initialscript.py", line 88, in missing_value_check
    df.replace('', np.nan) #from #https://towardsdatascience.com/data-cleaning-with-python-and-pandas-detecting-missing-values-3e9c6ebcf78b
    ^^^^^^^^^^
  File "C:\Users\Emmie\OneDrive - University of St Andrews\CS5002_P3\initialscript.py", line 106, in clean_data
    df, columns_with_missing, nan_values = missing_value_check(df)
                                           ^^^^^^^^^^^^^^^^^^^^^^^
  File "C:\Users\Emmie\OneDrive - University of St Andrews\CS5002_P3\initialscript.py", line 124, in <module>
    result_summary = clean_data(input_file, output_file)
                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
AttributeError: 'function' object has no attribute 'replace'

# %% [markdown]
# attribute error;

# %%
Exception has occurred: TypeError
load_df() missing 1 required positional argument: 'file_path'
  File "C:\Users\Emmie\OneDrive - University of St Andrews\CS5002_P3\initialscript.py", line 106, in clean_data
    df = load_df()
         ^^^^^^^^^
  File "C:\Users\Emmie\OneDrive - University of St Andrews\CS5002_P3\initialscript.py", line 124, in <module>
    result_summary = clean_data(input_file, output_file)
                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
TypeError: load_df() missing 1 required positional argument: 'file_path'

# %% [markdown]
# took out file_path from load file

# %%
Exception has occurred: UnboundLocalError
cannot access local variable 'df' where it is not associated with a value
  File "C:\Users\Emmie\OneDrive - University of St Andrews\CS5002_P3\initialscript.py", line 30, in get_expected_types_from_data_dictionary
    df = df.infer_objects()
         ^^
  File "C:\Users\Emmie\OneDrive - University of St Andrews\CS5002_P3\initialscript.py", line 108, in clean_data
    expected_types = get_expected_types_from_data_dictionary(df)
                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
  File "C:\Users\Emmie\OneDrive - University of St Andrews\CS5002_P3\initialscript.py", line 124, in <module>
    result_summary = clean_data(input_file, output_file)
                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
UnboundLocalError: cannot access local variable 'df' where it is not associated with a value

# %% [markdown]
# first sucesssful run without admissable
# Hello World!
# Column 'Record_Number converted to int64.
# Column 'Region converted to object.
# Column 'RESIDENCE_TYPE converted to object.
# Column 'Family_Composition converted to object.
# Column 'sex converted to int64.
# Column 'age converted to int64.
# Column 'Marital_Status converted to int64.
# Column 'student converted to int64.
# Column 'Country_Of_Birth converted to int64.
# Column 'health converted to int64.
# Column 'Ethnic_Group converted to int64.
# Column 'religion converted to int64.
# Column 'Economic_Activity converted to object.
# Column 'Occupation converted to object.
# Column 'industry converted to object.
# Column 'Hours_Worked_Per_Week converted to object.
# Column 'Approximate_Social_Grade converted to object.

# %%
Exception has occurred: AttributeError
'NoneType' object has no attribute 'duplicated'
  File "C:\Users\Emmie\OneDrive - University of St Andrews\CS5002_P3\initialscript.py", line 79, in duplicate_check
    duplicate_rows= df[df.duplicated()]
                       ^^^^^^^^^^^^^
  File "C:\Users\Emmie\OneDrive - University of St Andrews\CS5002_P3\initialscript.py", line 109, in clean_data
    df, duplicate_rows = duplicate_check(df)
                         ^^^^^^^^^^^^^^^^^^^
  File "C:\Users\Emmie\OneDrive - University of St Andrews\CS5002_P3\initialscript.py", line 122, in <module>
    result_summary = clean_data(input_file, output_file)
                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
AttributeError: 'NoneType' object has no attribute 'duplicated'

# %% [markdown]
# getting rid of none and sticking to pandas guide

# %%
forgot ot explictly map between types and data set

# %% [markdown]
# ##missing_values = ["n/a", "na", "--"]
# #df = pd.read_csv("property data.csv", na_values = missing_values) put this up here?

# %% [markdown]
#     duplicate_rows = df[df.duplicated()] wasnt working so i decided to drop it

# %% [markdown]
# how to use lambda, how i applied it
#
# https://www.geeksforgeeks.org/applying-lambda-functions-to-pandas-dataframe/
#
# def mapping_values(df, data_dict):
#     for column, mapping in data_dict.items():
#         if column in df.columns:
#             valid_values = list(mapping.keys())
#             df[column] = df[column].apply(lambda x: x if str(x) in valid_values else np.nan) #https://stackoverflow.com/questions/44061607/pandas-lambda-function-with-nan-support
#             print(f"Validated values in column '{column}'.")
#     return df #put this in duplicates?

# %%
  File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2032.0_x64__qbz5n2kfra8p0\Lib\runpy.py", line 88, in _run_code
    exec(code, run_globals)
  File "c:\Users\Emmie\.vscode\extensions\ms-python.debugpy-2024.12.0-win32-x64\bundled\libs\debugpy\adapter/../..\debugpy\launcher/../..\debugpy\__main__.py", line 71, in <module>
    cli.main()
  File "c:\Users\Emmie\.vscode\extensions\ms-python.debugpy-2024.12.0-win32-x64\bundled\libs\debugpy\adapter/../..\debugpy\launcher/../..\debugpy/..\debugpy\server\cli.py", line 501, in main
    run()
  File "c:\Users\Emmie\.vscode\extensions\ms-python.debugpy-2024.12.0-win32-x64\bundled\libs\debugpy\adapter/../..\debugpy\launcher/../..\debugpy/..\debugpy\server\cli.py", line 351, in run_file
    runpy.run_path(target, run_name="__main__")
  File "c:\Users\Emmie\.vscode\extensions\ms-python.debugpy-2024.12.0-win32-x64\bundled\libs\debugpy\_vendored\pydevd\_pydevd_bundle\pydevd_runpy.py", line 309, in run_path
    code, fname = _get_code_from_file(run_name, path_name)
                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
  File "c:\Users\Emmie\.vscode\extensions\ms-python.debugpy-2024.12.0-win32-x64\bundled\libs\debugpy\_vendored\pydevd\_pydevd_bundle\pydevd_runpy.py", line 283, in _get_code_from_file
    code = compile(f.read(), fname, "exec")
           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
  File "C:\Users\Emmie\OneDrive - University of St Andrews\CS5002_P3\initialscript.py", line 44
    elif isinstance(admissable, list):   #put list aswell as range
    ^^^^
SyntaxError: invalid syntax
PS C:\Users\Emmie\OneDrive - University of St Andrews\CS5002_P3> ^C
PS C:\Users\Emmie\OneDrive - University of St Andrews\CS5002_P3> 
PS C:\Users\Emmie\OneDrive - University of St Andrews\CS5002_P3>  c:; cd 'c:\Users\Emmie\OneDrive - University of St Andrews\CS5002_P3'; & 'c:\Users\Emmie\AppData\Local\Microsoft\WindowsApps\python3.12.exe' 'c:\Users\Emmie\.vscode\extensions\ms-python.debugpy-2024.12.0-win32-x64\bundled\libs\debugpy\adapter/../..\debugpy\launcher' '64252' '--' 'C:\Users\Emmie\OneDrive - University of St Andrews\CS5002_P3\initialscript.py' 
Traceback (most recent call last):
  File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2032.0_x64__qbz5n2kfra8p0\Lib\runpy.py", line 198, in _run_module_as_main  
    return _run_code(code, main_globals, None,
           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
  File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2032.0_x64__qbz5n2kfra8p0\Lib\runpy.py", line 88, in _run_code
    exec(code, run_globals)
  File "c:\Users\Emmie\.vscode\extensions\ms-python.debugpy-2024.12.0-win32-x64\bundled\libs\debugpy\adapter/../..\debugpy\launcher/../..\debugpy\__main__.py", line 71, in <module>
    cli.main()
  File "c:\Users\Emmie\.vscode\extensions\ms-python.debugpy-2024.12.0-win32-x64\bundled\libs\debugpy\adapter/../..\debugpy\launcher/../..\debugpy/..\debugpy\server\cli.py", line 501, in main
    run()
  File "c:\Users\Emmie\.vscode\extensions\ms-python.debugpy-2024.12.0-win32-x64\bundled\libs\debugpy\adapter/../..\debugpy\launcher/../..\debugpy/..\debugpy\server\cli.py", line 351, in run_file
    runpy.run_path(target, run_name="__main__")
  File "c:\Users\Emmie\.vscode\extensions\ms-python.debugpy-2024.12.0-win32-x64\bundled\libs\debugpy\_vendored\pydevd\_pydevd_bundle\pydevd_runpy.py", line 309, in run_path
    code, fname = _get_code_from_file(run_name, path_name)
                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
  File "c:\Users\Emmie\.vscode\extensions\ms-python.debugpy-2024.12.0-win32-x64\bundled\libs\debugpy\_vendored\pydevd\_pydevd_bundle\pydevd_runpy.py", line 283, in _get_code_from_file
    code = compile(f.read(), fname, "exec")
           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
  File "C:\Users\Emmie\OneDrive - University of St Andrews\CS5002_P3\initialscript.py", line 37
    for column, admissable in data_dict.items(): # Changes range_or_list to just refer to data_dict, to directly load what is admissible
                                                                                                                                        ^
IndentationError: unindent does not match any outer indentation level
PS C:\Users\Emmie\OneDrive - University of St Andrews\CS5002_P3>

# %% [markdown]
# indentation error

# %%
  File "c:\Users\Emmie\OneDrive - University of St Andrews\CS5002_P3\initialscript.py", line 37
    for column, admissable in data_dict.items(): # Changes range_or_list to just refer to data_dict, to directly load what is admissible
                                                                                                                                        ^
IndentationError: unindent does not match any outer indentation level
PS C:\Users\Emmie\OneDrive - University of St Andrews\CS5002_P3>

# %% [markdown]
# infer-na
#
# it is running but is not mapping the data how its specified in the brief, i have to redo the json file and the mapping allocation

# %%
Exception has occurred: UnboundLocalError
cannot access local variable 'df' where it is not associated with a value
  File "C:\Users\Emmie\OneDrive - University of St Andrews\CS5002_P3\code\data_cleaning.py", line 104, in clean_data
    print(f"Total number of records: {len(df)}")
                                          ^^
  File "C:\Users\Emmie\OneDrive - University of St Andrews\CS5002_P3\code\data_cleaning.py", line 116, in <module>
    clean_data()
UnboundLocalError: cannot access local variable 'df' where it is not associated with a value

# %%
C:\Users\Emmie\OneDrive - University of St Andrews\CS5002_P3\initialscript.py:88: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
  df[column] = df[column].map(mapping).fillna(np.nan
Validated values in column 'Country_Of_Birth'.
Validated values in column 'Economic_Activity'.
Validated values in column 'Occupation'.
Validated values in column 'Hours_Worked_Per_Week'.
Validated values in column 'Approximate_Social_Grade'.


def check_data_types(df):
    data_types = df.dtypes
    print("Data types of each variable:")
    print(data_types)
    return df


Data types of each variable:
Record_Number                 int64
Region                       object
RESIDENCE_TYPE               object
Family_Composition           object
sex                           int64
age                           int64
Marital_Status              float64
student                       int64
Country_Of_Birth            float64
health                        int64
Ethnic_Group                  int64
religion                      int64
Economic_Activity            object
Occupation                   object
industry                     object
Hours_Worked_Per_Week        object
Approximate_Social_Grade     object
dtype: object

dont think this is neccesary?


Cleaned data saved to 'data/refined_Scotland_teaching_file_1PCT.csv'.
PS C:\Users\Emmie\OneDrive - University of St Andrews\CS5002_P3>

# %%
#Combining duplicates, admissable and missing values into one function as I was having issues with calling them all at the end, duplicates was turning the data set into null.


    
    #for column, admissable in data_dict.items(): # Changes range_or_list to just refer to data_dict, to directly load what is admissible
      #  if column in df.columns:
       #     try:
        #        if isinstance(admissable, tuple):
         #           min_val, max_val = admissable
          #          df[column] = df[column].between(min_val, max_val, inclusive='both').replace({False: np.nan}) #https://stackoverflow.com/questions/29247712/how-to-replace-a-value-in-pandas-with-nan
           #         print(f"Column '{column}' values checked within range ({min_val}, {max_val})")
             #   elif isinstance(admissable, list):
            #        df[column] = df[column].where(df[column].isin(admissable), np.nan)
              #      print(f"Column '{column}' values checked against admissible list.")
            #except ValueError as error:
            #    print(f"Error checking columns for admissible values: {error}")

                # no admissable returns are being returned in terminal, redo, should map to json to get range of possible values?
                
#missing values, replace with nan, havent defined the range properly, have to explicitly outline

    #df.replace('', np.nan) #from #https://towardsdatascience.com/data-cleaning-with-python-and-pandas-detecting-missing-values-3e9c6ebcf78b
    #nan_values = df[df.isna().any(axis=1)]
    #missing_summary = df.isna().sum()
    #columns_with_missing_value = [] #null, caused issues with converting data set to none, will have to revamp
    #for column, missing_count in missing_summary.items():
     #   if missing_count  > 0: 
      #      columns_with_missing_value.append((column, missing_count))

# %% [markdown]
# #https://www.analyticsvidhya.com/blog/2024/05/automate-data-cleaning-in-python/
# #https://stackoverflow.com/questions/20199126/reading-json-from-a-file
# #https://www.analyticsvidhya.com/blog/2024/05/automate-data-cleaning-in-python/
#             #print missing value return in terminal
#
#
# #https://www.geeksforgeeks.org/applying-lambda-functions-to-pandas-dataframe/
# #https://www.slingacademy.com/article/exploring-pandas-dataframe-isin-method/
# #https://blog.finxter.com/5-best-ways-to-check-if-values-fall-within-intervals-using-pythons-pandas/
# #https://stackoverflow.com/questions/40156469/how-to-check-if-any-value-of-a-column-is-in-a-range-in-between-two-values-in-p
# #https://stackoverflow.com/questions/13921707/check-if-numbers-are-in-a-certain-range-in-python-with-a-loop
# #https://www.w3resource.com/python-exercises/python-functions-exercise-6.php
# #https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.duplicated.html
#  #https://stackoverflow.com/questions/14657241/how-do-i-get-a-list-of-all-the-duplicate-items-using-pandas-in-python
#  #https://towardsdatascience.com/data-cleaning-with-python-and-pandas-detecting-missing-values-3e9c6ebcf78b
# #https://stackoverflow.com/questions/27159189/find-empty-or-nan-entry-in-pandas-dataframe
#
#
#         #https://realpython.com/python-data-cleaning-numpy-pandas/
#         #https://blog.finxter.com/5-best-ways-to-convert-data-types-in-a-pandas-dataframe-with-python/

# %% [markdown]
# #def mapping_values(df, data_dict):
#  #   for column, mapping in data_dict.items():
#   #      if column in df.columns:
#    #         valid_values = list(mapping.keys())
#     #        df[column] = df[column].where(df[column].isin(valid_values), np.nan)
#      #       print(f"Validated values in column '{column}'.")
#     #return df
#
#
#     i mapped the values and transformed them into the literary values, inorder to create the bargraph and import labels easily, but this was redundamt so it was cut

# %% [markdown]
# I made the code too complex from the start, due to the stack overflow references, I restarted and used the pandas documentation and the following youtube videos:

# %% [markdown]
# age in the csv file is lower case: add automatic lower case to csv file and data dictionary?
